# %%
# Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %% [markdown]
# ****This above cell was last run on 12-01-2021, The dataset below is as of 12-01-2021.**

# %%
df
# Loading dataset
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands       0     10751     10622
# 1     2                            Andhra Pradesh      16   2339116   2324367
# 2     3                         Arunachal Pradesh       0     66891     66595
# 3     4                                     Assam       2    746102    738065
# 4     5                                     Bihar       8    851435    839124
# 5     6                                Chandigarh      24     99401     98195
# 6     7                              Chhattisgarh       7   1177814   1163660
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11591     11587
# 8     9                                     Delhi     292   2008171   1981355
# 9    10                                      Goa*     137    259344    255194
# 10   11                                   Gujarat    1064   1279257   1267144
# 11   12                                   Haryana     124   1056956   1046118
# 12   13                          Himachal Pradesh     232    313166    308719
# 13   14                         Jammu and Kashmir      77    479600    474738
# 14   15                                 Jharkhand      21    442602    437249
# 15   16                                 Karnataka     658   4075742   4034765
# 16   17                                 Kerala***    2009   6832851   6759245
# 17   18                                    Ladakh       4     29432     29197
# 18   19                               Lakshadweep       0     11415     11363
# 19   20                            Madhya Pradesh      35   1055031   1044219
# 20   21                               Maharashtra    1648   8140479   7990401
# 21   22                                   Manipur       0    139924    137775
# 22   23                                 Meghalaya       1     96789     95163
# 23   24                                   Mizoram       0    238969    238243
# 24   25                                  Nagaland       0     35988     35206
# 25   26                                    Odisha      59   1336800   1327483
# 26   27                                Puducherry      68    175991    173947
# 27   28                                  Punjab**      97    785873    765260
# 28   29                                 Rajasthan     163   1315844   1306021
# 29   30                                    Sikkim       4     44333     43829
# 30   31                                Tamil Nadu     480   3595839   3557309
# 31   32                                 Telangana     153    842304    838040
# 32   33                                   Tripura       0    108034    107094
# 33   34                               Uttarakhand      41    449549    441754
# 34   35                             Uttar Pradesh     132   2128399   2104618
# 35   36                               West Bengal      49   2118915   2097333
# 36   37                                              7605  44700698  44160997
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           0         10751      10622        129
# 1    14733          16       2339118    2324369      14733
# 2      296           0         66891      66595        296
# 3     8035           2        746102     738065       8035
# 4    12303           7        851435     839125      12303
# 5     1182          26         99406      98198       1182
# 6    14147           9       1177816    1163660      14147
# 7        4           0         11591      11587          4
# 8    26524         346       2008288    1981418      26524
# 9     4013         142        259360     255205       4013
# 10   11049        1179       1279519    1267290      11050
# 11   10714         126       1056981    1046141      10714
# 12    4215         285        313239     308739       4215
# 13    4785          79        479608     474744       4785
# 14    5332          22        442604     437250       5332
# 15   40319         631       4075853    4034902      40320
# 16   71597        2090       6833061    6759374      71597
# 17     231           3         29432      29198        231
# 18      52           0         11415      11363         52
# 19   10777          47       1055046    1044222      10777
# 20  148430        1617       8140677    7990630     148430
# 21    2149           0        139924     137775       2149
# 22    1625           2         96790      95163       1625
# 23     726           0        238969     238243        726
# 24     782           0         35988      35206        782
# 25    9205          73       1336817    1327486       9205
# 26    1976          56        175996     173964       1976
# 27   19289         103        785891     765272      19289
# 28    9660         184       1315865    1306021       9660
# 29     500           5         44334      43829        500
# 30   38050         517       3595925    3557358      38050
# 31    4111         146        842324     838067       4111
# 32     940           0        108034     107094        940
# 33    7754          24        449553     441775       7754
# 34   23649         140       2128425    2104636      23649
# 35   21533          50       2118919    2097336      21533
# 36  530816        7927      44701947   44161922     530818
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10     1          24                 1
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15     1          29                 1
# 16                32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23                15                 0
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34                 9                 0
# 35                19                 0
# 36     2           0                 2

# %% [markdown]
# **Data Understanding**

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 14)

# %%
df.isnull().sum()
# no null values
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# actualdeath24hrs    0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
#  13  actualdeath24hrs  37 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 4.2+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#              sno       active      positive         cured          death  \
# count  37.000000    37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000   411.081081  2.416254e+06  2.387081e+06   28692.756757
# std    10.824355  1295.309216  7.370133e+06  7.280210e+06   88971.816745
# min     1.000000     0.000000  1.075100e+04  1.062200e+04       4.000000
# 25%    10.000000     2.000000  1.080340e+05  1.070940e+05    1182.000000
# 50%    19.000000    41.000000  7.461020e+05  7.380650e+05    7754.000000
# 75%    28.000000   153.000000  1.336800e+06  1.327483e+06   14733.000000
# max    37.000000  7605.000000  4.470070e+07  4.416100e+07  530816.000000
#
#         new_active  new_positive     new_cured      new_death  state_code  \
# count    37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean    428.486486  2.416321e+06  2.387131e+06   28692.864865   18.324324
# std    1348.109018  7.370338e+06  7.280364e+06   88972.128401   11.212726
# min       0.000000  1.075100e+04  1.062200e+04       4.000000    0.000000
# 25%       2.000000  1.080340e+05  1.070940e+05    1182.000000    9.000000
# 50%      47.000000  7.461020e+05  7.380650e+05    7754.000000   18.000000
# 75%     146.000000  1.336817e+06  1.327486e+06   14733.000000   28.000000
# max    7927.000000  4.470195e+07  4.416192e+07  530818.000000   37.000000
#
#        actualdeath24hrs
# count         37.000000
# mean           0.108108
# std            0.393262
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            2.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno                 37
# state_name          37
# active              29
# positive            37
# cured               37
# death               37
# new_active          29
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     1
# total                3
# state_code          37
# actualdeath24hrs     3
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura       0    108034    107094     940           0
# 33   34    Uttarakhand      41    449549    441754    7754          24
# 34   35  Uttar Pradesh     132   2128399   2104618   23649         140
# 35   36    West Bengal      49   2118915   2097333   21533          50
# 36   37                   7605  44700698  44160997  530816        7927
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 32        108034     107094        940                                 16
# 33        449553     441775       7754                                  5
# 34       2128425    2104636      23649                                  9
# 35       2118919    2097336      21533                                 19
# 36      44701947   44161922     530818                      2           0
#
#     actualdeath24hrs
# 32                 0
# 33                 0
# 34                 0
# 35                 0
# 36                 2

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# This is the dataset that we are to work on
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands       0     10751    10622
# 1     2                            Andhra Pradesh      16   2339116  2324367
# 2     3                         Arunachal Pradesh       0     66891    66595
# 3     4                                     Assam       2    746102   738065
# 4     5                                     Bihar       8    851435   839124
# 5     6                                Chandigarh      24     99401    98195
# 6     7                              Chhattisgarh       7   1177814  1163660
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11591    11587
# 8     9                                     Delhi     292   2008171  1981355
# 9    10                                      Goa*     137    259344   255194
# 10   11                                   Gujarat    1064   1279257  1267144
# 11   12                                   Haryana     124   1056956  1046118
# 12   13                          Himachal Pradesh     232    313166   308719
# 13   14                         Jammu and Kashmir      77    479600   474738
# 14   15                                 Jharkhand      21    442602   437249
# 15   16                                 Karnataka     658   4075742  4034765
# 16   17                                 Kerala***    2009   6832851  6759245
# 17   18                                    Ladakh       4     29432    29197
# 18   19                               Lakshadweep       0     11415    11363
# 19   20                            Madhya Pradesh      35   1055031  1044219
# 20   21                               Maharashtra    1648   8140479  7990401
# 21   22                                   Manipur       0    139924   137775
# 22   23                                 Meghalaya       1     96789    95163
# 23   24                                   Mizoram       0    238969   238243
# 24   25                                  Nagaland       0     35988    35206
# 25   26                                    Odisha      59   1336800  1327483
# 26   27                                Puducherry      68    175991   173947
# 27   28                                  Punjab**      97    785873   765260
# 28   29                                 Rajasthan     163   1315844  1306021
# 29   30                                    Sikkim       4     44333    43829
# 30   31                                Tamil Nadu     480   3595839  3557309
# 31   32                                 Telangana     153    842304   838040
# 32   33                                   Tripura       0    108034   107094
# 33   34                               Uttarakhand      41    449549   441754
# 34   35                             Uttar Pradesh     132   2128399  2104618
# 35   36                               West Bengal      49   2118915  2097333
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           0         10751      10622        129
# 1    14733          16       2339118    2324369      14733
# 2      296           0         66891      66595        296
# 3     8035           2        746102     738065       8035
# 4    12303           7        851435     839125      12303
# 5     1182          26         99406      98198       1182
# 6    14147           9       1177816    1163660      14147
# 7        4           0         11591      11587          4
# 8    26524         346       2008288    1981418      26524
# 9     4013         142        259360     255205       4013
# 10   11049        1179       1279519    1267290      11050
# 11   10714         126       1056981    1046141      10714
# 12    4215         285        313239     308739       4215
# 13    4785          79        479608     474744       4785
# 14    5332          22        442604     437250       5332
# 15   40319         631       4075853    4034902      40320
# 16   71597        2090       6833061    6759374      71597
# 17     231           3         29432      29198        231
# 18      52           0         11415      11363         52
# 19   10777          47       1055046    1044222      10777
# 20  148430        1617       8140677    7990630     148430
# 21    2149           0        139924     137775       2149
# 22    1625           2         96790      95163       1625
# 23     726           0        238969     238243        726
# 24     782           0         35988      35206        782
# 25    9205          73       1336817    1327486       9205
# 26    1976          56        175996     173964       1976
# 27   19289         103        785891     765272      19289
# 28    9660         184       1315865    1306021       9660
# 29     500           5         44334      43829        500
# 30   38050         517       3595925    3557358      38050
# 31    4111         146        842324     838067       4111
# 32     940           0        108034     107094        940
# 33    7754          24        449553     441775       7754
# 34   23649         140       2128425    2104636      23649
# 35   21533          50       2118919    2097336      21533
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10     1          24                 1
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15     1          29                 1
# 16                32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23                15                 0
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34                 9                 0
# 35                19                 0

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 7605

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 44700698

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 44160997

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 530816

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 7927

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 44701947

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 44161922

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 530818

# %% [markdown]
# **Data Visualization**

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                               666
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                           7605
# positive                                                     44700698
# cured                                                        44160997
# death                                                          530816
# new_active                                                       7927
# new_positive                                                 44701947
# new_cured                                                    44161922
# new_death                                                      530818
# death_reconsille
# total                                                              11
# state_code                                                        678
# actualdeath24hrs                                                    2
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active                  7605
# positive            44700698
# cured               44160997
# death                 530816
# new_active              7927
# new_positive        44701947
# new_cured           44161922
# new_death             530818
# death_reconsille
# total                     11
# actualdeath24hrs           2
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# <ipython-input-44-4b77f564f2d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['sno','state_code'],axis=1,inplace=True)

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       0     10751    10622    129           0
# 1               Andhra Pradesh      16   2339116  2324367  14733          16
# 2            Arunachal Pradesh       0     66891    66595    296           0
# 3                        Assam       2    746102   738065   8035           2
# 4                        Bihar       8    851435   839124  12303           7
#
#    new_positive  new_cured  new_death death_reconsille total  actualdeath24hrs
# 0         10751      10622        129                                        0
# 1       2339118    2324369      14733                                        0
# 2         66891      66595        296                                        0
# 3        746102     738065       8035                                        0
# 4        851435     839125      12303                                        0

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands       0     10751    10622    129           0
# Andhra Pradesh                   16   2339116  2324367  14733          16
# Arunachal Pradesh                 0     66891    66595    296           0
# Assam                             2    746102   738065   8035           2
# Bihar                             8    851435   839124  12303           7
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10751      10622        129
# Andhra Pradesh                    2339118    2324369      14733
# Arunachal Pradesh                   66891      66595        296
# Assam                              746102     738065       8035
# Bihar                              851435     839125      12303
#
#                             death_reconsille total  actualdeath24hrs
# state_name
# Andaman and Nicobar Islands                                        0
# Andhra Pradesh                                                     0
# Arunachal Pradesh                                                  0
# Assam                                                              0
# Bihar                                                              0

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <Axes: ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <Axes: ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <Axes: ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <Axes: ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <Axes: ylabel='state_name'>
